# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 913.5/913.5 kB 52.5 MB/s eta 0:00:00
# ...

# %%
# three types of modes
# train
# Val
# predict

# three types of tasks
# detect
# segment
# classify

# %% [markdown]
# CLI method

# %%
# !yolo predict model = yolov8n.pt source = "https://wallpapercrafter.com/desktop3/911375-people-car-human-person-taxi-transportation-vehicle.jpg"
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 6.25M/6.25M [00:00<00:00, 275MB/s]
# Ultralytics 8.3.67 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# ⚠️ Download failure, retrying 1/3 https://wallpapercrafter.com/desktop3/911375-people-car-human-person-taxi-transportation-vehicle.jpg...
# ############################################################################################# 100.0%
# image 1/1 /content/911375-people-car-human-person-taxi-transportation-vehicle.jpg: 448x640 3 persons, 1 truck, 36.7ms
# Speed: 12.6ms preprocess, 36.7ms inference, 843.2ms postprocess per image at shape (1, 3, 448, 640)
# ...

# %% [markdown]
# Python method

# %%
from ultralytics import YOLO
model = YOLO("yolo11n-seg.pt")
model.predict(source = "https://domf5oio6qrcr.cloudfront.net/medialibrary/8617/dog-park-petting-dog.jpg" )
# Out:
# ...
# 100%|██████████| 5.90M/5.90M [00:00<00:00, 112MB/s]
# ...
# 100%|██████████| 216k/216k [00:00<00:00, 7.67MB/s]
# image 1/1 /content/dog-park-petting-dog.jpg: 448x640 4 persons, 1 dog, 97.0ms
# Speed: 6.0ms preprocess, 97.0ms inference, 998.3ms postprocess per image at shape (1, 3, 448, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.67 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 31.1/112.6 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/YOLO/Dataset
# Out:
# /content/drive/MyDrive/YOLO/Dataset

# %%
# %cd /content/drive/MyDrive/YOLO/Dataset

# !yolo task=detect mode=train model=yolov8s.pt data=data.yaml epochs=15 imgsz=640 plots=True
# Out:
# /content/drive/MyDrive/YOLO/Dataset
# Ultralytics 8.3.65 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls runs/detect/train3
# Out:
# args.yaml					    labels.jpg	  train_batch0.jpg
# confusion_matrix_normalized.png			    P_curve.png   train_batch1.jpg
# confusion_matrix.png				    PR_curve.png  train_batch2.jpg
# events.out.tfevents.1737617140.c0732f8203bf.4567.0  R_curve.png   val_batch0_labels.jpg
# F1_curve.png					    results.csv   val_batch0_pred.jpg
# labels_correlogram.jpg				    results.png   weights

# %%
Image(filename='runs/detect/train3/confusion_matrix.png', width=600)

# %%
Image(filename='runs/detect/train3/results.png', width=600)

# %%
Image(filename='runs/detect/train3/val_batch0_pred.jpg',width=600)

# %%
# !yolo task=detect mode=val model=runs/detect/train3/weights/best.pt conf=0.5 data=data.yaml
# Out:
# Ultralytics 8.3.65 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,162,736 parameters, 0 gradients, 28.6 GFLOPs
# val: Scanning /content/drive/MyDrive/YOLO/Dataset/valid/labels.cache... 25 images, 0 backgrounds, 0 corrupt: 100% 25/25 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 8, len(boxes) = 134. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.53it/s]
#                    all         25        134     0.0436     0.0223     0.0329     0.0207
#                 Person          3         14          0          0          0          0
#               airplane          1          1          0          0          0          0
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train3/weights/best.pt conf=0.5 source=/content/drive/MyDrive/YOLO/Dataset/test/images
# Out:
# Ultralytics 8.3.65 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,162,736 parameters, 0 gradients, 28.6 GFLOPs
#
# image 1/13 /content/drive/MyDrive/YOLO/Dataset/test/images/000000000009_jpg.rf.68a184c9f7b52d24ada91a4b499edb17.jpg: 640x640 (no detections), 16.7ms
# image 2/13 /content/drive/MyDrive/YOLO/Dataset/test/images/000000000049_jpg.rf.66b9be5a8ac3fbf6e9301c9dd6cabbaa.jpg: 640x640 (no detections), 16.6ms
# image 3/13 /content/drive/MyDrive/YOLO/Dataset/test/images/000000000077_jpg.rf.4d12c03dbdfb28aa062a2b581d541400.jpg: 640x640 4 persons, 16.5ms
# image 4/13 /content/drive/MyDrive/YOLO/Dataset/test/images/000000000078_jpg.rf.23440ccbe3bb274c1a1fdcb128b00039.jpg: 640x640 (no detections), 16.5ms
# image 5/13 /content/drive/MyDrive/YOLO/Dataset/test/images/000000000094_jpg.rf.5fcd773e77ac4f62791530f130b75b10.jpg: 640x640 (no detections), 16.5ms
# ...

# %%
import glob
from IPython.display import Image, display
for image_path in glob.glob('/content/drive/MyDrive/YOLO/Dataset/runs/detect/predict*.jpg')[:3]:
  display(Image(filename=image_path, width=600))
  print("\n")

# %%
from ultralytics import YOLO
model = YOLO("best.pt")
model.predict(source = "https://domf5oio6qrcr.cloudfront.net/medialibrary/8617/dog-park-petting-dog.jpg" )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-0ad4c6d745fc> in <cell line: 0>()
#       1 from ultralytics import YOLO
# ----> 2 model = YOLO("best.pt")
#       3 model.predict(source = "https://domf5oio6qrcr.cloudfront.net/medialibrary/8617/dog-park-petting-dog.jpg" )
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/models/yolo/model.py in __init__(self, model, task, verbose)
#      21         else:
#      22             # Continue with default YOLO initialization
# ---> 23             super().__init__(model=model, task=task, verbose=verbose)
#      24
#      25     @property
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py in __init__(self, model, task, verbose)
#     144             self._new(model, task=task, verbose=verbose)
#     145         else:
# --> 146             self._load(model, task=task)
#     147
# ...

# %%
# !yolo predict task=detect mode=predict model=runs/detect/train3/weights/best.pt source = "https://wallpapercrafter.com/desktop3/911375-people-car-human-person-taxi-transportation-vehicle.jpg"
# Out:
# Ultralytics 8.3.65 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,162,736 parameters, 0 gradients, 28.6 GFLOPs
#
# ...
# ⚠️ Download failure, retrying 1/3 https://wallpapercrafter.com/desktop3/911375-people-car-human-person-taxi-transportation-vehicle.jpg...
# ############################################################################################# 100.0%
# image 1/1 /content/drive/MyDrive/YOLO/Dataset/911375-people-car-human-person-taxi-transportation-vehicle.jpg: 448x640 3 persons, 39.6ms
# Speed: 4.0ms preprocess, 39.6ms inference, 646.2ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
